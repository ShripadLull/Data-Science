# %%
# !pip install jupyter_contrib_nbextensions
# Out:
# [I 12:13:43 InstallContribNbextensionsApp] Copying: C:\Users\Shripad Lull\anaconda3\lib\site-packages\jupyter_contrib_nbextensions\nbextensions\keyboard_shortcut_editor\icon.png -> C:\Users\Shripad Lull\AppData\Roaming\jupyter\nbextensions\keyboard_shortcut_editor\icon.png
# [I 12:13:43 InstallContribNbextensionsApp] Copying: C:\Users\Shripad Lull\anaconda3\lib\site-packages\jupyter_contrib_nbextensions\nbextensions\keyboard_shortcut_editor\keyboard_shortcut_editor.yaml -> C:\Users\Shripad Lull\AppData\Roaming\jupyter\nbextensions\keyboard_shortcut_editor\keyboard_shortcut_editor.yaml
# [I 12:13:43 InstallContribNbextensionsApp] Copying: C:\Users\Shripad Lull\anaconda3\lib\site-packages\jupyter_contrib_nbextensions\nbextensions\keyboard_shortcut_editor\kse_components.js -> C:\Users\Shripad Lull\AppData\Roaming\jupyter\nbextensions\keyboard_shortcut_editor\kse_components.js
# ...

# %%
# !jupyter contrib nbextension install --user
# Out:
# [I 12:13:43 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 12:13:43 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 12:13:43 InstallContribNbextensionsApp] Installing C:\Users\Shripad Lull\anaconda3\lib\site-packages\jupyter_contrib_nbextensions\nbextensions\addbefore -> addbefore
# [I 12:13:43 InstallContribNbextensionsApp] Making directory: C:\Users\Shripad Lull\AppData\Roaming\jupyter\nbextensions\addbefore\
# [I 12:13:43 InstallContribNbextensionsApp] Copying: C:\Users\Shripad Lull\anaconda3\lib\site-packages\jupyter_contrib_nbextensions\nbextensions\addbefore\addbefore.yaml -> C:\Users\Shripad Lull\AppData\Roaming\jupyter\nbextensions\addbefore\addbefore.yaml
# ...

# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("E:/Data Science/Salaries.csv")

# %%
df.head(50)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.shape
# Out:
# (78, 6)

# %%
df.sample(5)
# Out:
#         rank discipline  phd  service     sex  salary
# 44      Prof          B   23       19  Female  151768
# 35      Prof          B   28       23    Male  126933
# 17  AsstProf          B    4        0    Male   92000
# 7       Prof          A   18       18    Male  126300
# 13      Prof          B   35       33    Male  162200

# %%
df.std()
# Out:
# C:\Users\Shripad Lull\AppData\Local\Temp\ipykernel_20112\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df1 = df.head(50)

# %%
df1.mean()
# Out:
# C:\Users\Shripad Lull\AppData\Local\Temp\ipykernel_20112\2053335143.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.head(50).mean()
# Out:
# C:\Users\Shripad Lull\AppData\Local\Temp\ipykernel_20112\1648960742.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.head(50).mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df['rank']
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df['salary'].head(50).mean()
# Out:
# 113789.14

# %%
df2 = df.groupby('rank').mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df2.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348
